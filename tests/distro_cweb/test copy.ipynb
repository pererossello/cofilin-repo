# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import numpyro
print(jax.devices())

jax.config.update("jax_enable_x64", True)

sys.path.append('../')

from cofilin.forward_model.config import Constants, FMConfig
from cofilin.forward_model.fmodel import FModel
from cofilin.forward_model.fourier import my_ifft
from cofilin.forward_model.bias import manage_params
from cofilin.forward_model.stats import get_pow_spec_1D, get_pow_spec_quadrupole
from cofilin.forward_model.plot_utils import plot_cubes, compare_pow_spec
# Out:
# [cuda(id=0)]

# %%
N, Z_I, Z_F = 256, 99, 0
R = 3.906
L = R * N
lpt_method = "ALPT"

MND = 1e-2
N_TR = MND * L**3

fm_cfg = FMConfig(
    N,
    L,
    Z_I,
    Z_F,
    rsd=False, 
    lpt_method=lpt_method,
    cweb = 'PhiWeb', 
    N_TR=N_TR
)
fmodel = FModel(fm_cfg)

# %%
q = fmodel.input_arr(jax.random.PRNGKey(1))
delta_lpt = fmodel.delta_lpt(q)
cweb = fmodel.cweb(delta_lpt)
# Out:
# 2025-05-20 14:41:15.019707: W external/xla/xla/tsl/framework/bfc_allocator.cc:482] Allocator (GPU_0_bfc) ran out of memory trying to allocate 387.00MiB (rounded to 405798912)requested by op
# 2025-05-20 14:41:15.020070: W external/xla/xla/tsl/framework/bfc_allocator.cc:494] ****____*****************************************xx**********************xxx**********************xx
# E0520 14:41:15.020120  152773 pjrt_stream_executor_client.cc:2985] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 405798912 bytes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 q = fmodel.input_arr(jax.random.PRNGKey(1))
# ----> 2 delta_lpt = fmodel.delta_lpt(q)
#       3 cweb = fmodel.cweb(delta_lpt)
#
# File ~/Documents/tfm/code_v3/cofilin-repo/cofilin/forward_model/fmodel.py:54, in FModel.delta_lpt(self, x)
#      52 def delta_lpt(self, x=None):
#      53     f = lambda q: get_delta_lpt(self.delta_in(q), cte=self.cte, fm_cfg=self.fm_cfg)
# ---> 54     return f if x is None else f(x)
#
# File ~/Documents/tfm/code_v3/cofilin-repo/cofilin/forward_model/fmodel.py:53, in FModel.delta_lpt.<locals>.<lambda>(q)
#      52 def delta_lpt(self, x=None):
# ---> 53     f = lambda q: get_delta_lpt(self.delta_in(q), cte=self.cte, fm_cfg=self.fm_cfg)
#      54     return f if x is None else f(x)
#
# File ~/Documents/tfm/code_v3/cofilin-repo/cofilin/forward_model/lpt.py:12, in get_delta_lpt(delta, cte, fm_cfg)
#      10 def get_delta_lpt(delta, cte: Constants, fm_cfg: FMConfig):
# ---> 12     psi = get_psi(delta, cte, fm_cfg)
#      13     pos = displace_particles(psi, cte, fm_cfg)
#      14     delta = particle_to_mesh(pos, cte)
#
# File ~/Documents/tfm/code_v3/cofilin-repo/cofilin/forward_model/lpt.py:58, in get_psi(delta, cte, fm_cfg, **kwargs)
#      56     return get_psi_sc(delta, cte=cte, fm_cfg=fm_cfg)
#      57 elif fm_cfg.lpt_method == "ALPT":
# ---> 58     return get_psi_alpt(delta, cte=cte, fm_cfg=fm_cfg)
#
# File ~/Documents/tfm/code_v3/cofilin-repo/cofilin/forward_model/lpt.py:209, in get_psi_alpt(delta_in_hat, cte, fm_cfg)
#     206 delta_in = my_ifft(delta_in_hat, INV_L3)
#     208 psi_sc = get_psi_sc(delta_in, cte, fm_cfg)
# --> 209 psi_lpt2 = get_psi_lpt2(delta_in_hat, cte, fm_cfg)
#     211 one_over_var_k = fm_cfg.r_s**2
#     212 k_sq = get_k_sq(cte.N, cte.L)
#
# File ~/Documents/tfm/code_v3/cofilin-repo/cofilin/forward_model/lpt.py:141, in get_psi_lpt2(delta_hat, cte, fm_cfg)
#     138 f1, f2 = cte.f1, cte.f2
#     140 psi1 = get_psi_lpt1(delta_hat, cte, fm_cfg)
# --> 141 psi2 = get_psi_o2(psi1, cte, fm_cfg)
#     143 psi = psi1 * D1 + psi2 * D2
#     145 if fm_cfg.rsd and (fm_cfg.lpt_method == "2LPT"):
#
# File ~/Documents/tfm/code_v3/cofilin-repo/cofilin/forward_model/lpt.py:128, in get_psi_o2(psi1, cte, fm_cfg)
#     125 phi2_hat = -arr * fm_cfg.one_over_k_sq
#     127 if fm_cfg.der_method == "FR":
# --> 128     psi2 = gradient_hat(phi2_hat, kx, ky, kz)
#     129 if fm_cfg.der_method == "FD":
#     130     psi2 = gradient_fd(my_ifft(phi2_hat, cte.INV_L3), cte.N, cte.L)
#
# File ~/Documents/tfm/code_v3/cofilin-repo/cofilin/forward_model/calculus.py:21, in gradient_hat(array_hat, kx, ky, kz)
#      20 def gradient_hat(array_hat, kx, ky, kz):
# ---> 21     return 1j * jnp.asarray([kx * array_hat, ky * array_hat, kz * array_hat])
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3289, in asarray(a, dtype, order, copy)
#    3287 if dtype is not None:
#    3288   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
# -> 3289 return array(a, dtype=dtype, copy=bool(copy), order=order)
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3204, in array(object, dtype, copy, order, ndmin)
#    3202 elif isinstance(object, (list, tuple)):
#    3203   if object:
# -> 3204     out = stack([asarray(elt, dtype=dtype) for elt in object])
#    3205   else:
#    3206     out = np.array([], dtype=dtype)
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:2843, in stack(arrays, axis, out, dtype)
#    2841     raise ValueError("All input arrays must have the same shape.")
#    2842   new_arrays.append(expand_dims(a, axis))
# -> 2843 return concatenate(new_arrays, axis=axis, dtype=dtype)
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:2911, in concatenate(arrays, axis, dtype)
#    2909 k = 16
#    2910 while len(arrays_out) > 1:
# -> 2911   arrays_out = [lax.concatenate(arrays_out[i:i+k], axis)
#    2912                 for i in range(0, len(arrays_out), k)]
#    2913 return arrays_out[0]
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:2911, in <listcomp>(.0)
#    2909 k = 16
#    2910 while len(arrays_out) > 1:
# -> 2911   arrays_out = [lax.concatenate(arrays_out[i:i+k], axis)
#    2912                 for i in range(0, len(arrays_out), k)]
#    2913 return arrays_out[0]
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/lax/lax.py:623, in concatenate(operands, dimension)
#     621   if isinstance(op, Array):
#     622     return type_cast(Array, op)
# --> 623 return concatenate_p.bind(*operands, dimension=dimension)
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/core.py:416, in Primitive.bind(self, *args, **params)
#     413 def bind(self, *args, **params):
#     414   assert (not config.enable_checks.value or
#     415           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 416   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/core.py:921, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     919   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     920 else:
# --> 921   return primitive.impl(*tracers, **params)
#
# File ~/Documents/tfm/envs/cosmo-env-gpu-py39/lib/python3.9/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
# ValueError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 405798912 bytes.

# %%
fig, ax = plot_cubes(
    [delta_lpt, cweb],
    cmap=["gnuplot", 'jet'],
    vlim=[(-1, 10),(0,3)],
    width=1, axis=2, idx=N//2,
    figsize=7.5
)

# %%
N3 = N**3
rho_lpt = 1+delta_lpt

rho_V = rho_lpt[cweb==0]
rho_S = rho_lpt[cweb==1]
rho_F = rho_lpt[cweb==2]
rho_K = rho_lpt[cweb==3]

cells_V = jnp.sum(cweb==0)
cells_S = jnp.sum(cweb==1)
cells_F = jnp.sum(cweb==2)
cells_K = jnp.sum(cweb==3)

mean_rho_V = jnp.sum(rho_V) / cells_V
mean_rho_S = jnp.sum(rho_S) / cells_S
mean_rho_F = jnp.sum(rho_F) / cells_F
mean_rho_K = jnp.sum(rho_K) / cells_K


print(f"Total: {rho_lpt.min():0.2f}, {rho_lpt.max():0.2f}")
print(f"V: {100*cells_V/N3:0.2f}, {mean_rho_V:0.04f}, ({rho_V.min():0.2f}, {rho_V.max():0.2f})")
print(f"S: {100*cells_S/N3:0.2f}, {mean_rho_S:0.04f}, ({rho_S.min():0.2f}, {rho_S.max():0.2f})")
print(f"F: {100*cells_F/N3:0.2f}, {mean_rho_F:0.04f}, ({rho_F.min():0.2f}, {rho_F.max():0.2f})")
print(f"K: {100*cells_K/N3:0.2f}, {mean_rho_K:0.04f}, ({rho_K.min():0.2f}, {rho_K.max():0.2f})")
# Out:
# Total: 0.00, 67.13
# V: 20.01, 0.2242, (0.00, 1.05)
# S: 54.91, 0.6433, (0.00, 9.25)
# F: 23.15, 2.0923, (0.00, 28.82)
# K: 1.93, 6.1049, (1.30, 67.13)

# %%
bins = jnp.linspace(0, 20, 200)

bins = jnp.logspace(-5, 2, 200)


dist, bin_edges = jnp.histogram(rho_lpt, bins)
dist_V, bin_edges = jnp.histogram(rho_V, bins)
dist_S, bin_edges = jnp.histogram(rho_S, bins)
dist_F, bin_edges = jnp.histogram(rho_F, bins)
dist_K, bin_edges = jnp.histogram(rho_K, bins)

bin_difs = bins[1:]-bins[:-1]
bin_centers = bin_difs*0.5

dists = [dist_V, dist_S, dist_F, dist_K, dist]

# bins = jnp.linspace(0, 10, 100)

# dist_V, bin_edges = jnp.histogram(rho_V, bins)
# dist_S, bin_edges = jnp.histogram(rho_S, bins)

# bin_difs = bins[1:]-bins[:-1]
# bin_centers = bin_difs*0.5

# %%
fs, rat = 7, 2.5
fig, ax = plt.subplots(1, 1, figsize=(fs * rat, fs))

lw = 0.25*fs
alpha = 1
cs = ["b", "r", "g", "y", 'k']

for i in range(5):
    ax.step(
        bins[:-1] + bin_difs / 2,
        dists[i],
        where='mid',
        color=cs[i],
        alpha=alpha,
        zorder=10,
        linewidth=lw,
    )

# ax.bar(
#     bins[:-1],
#     dist_K,
#     width=bin_difs,
#     alpha=0.1,
#     ec=cs[3],
#     facecolor=cs[3],
#     zorder=10,
#     lw=0,
# )


ax.grid(True, alpha=0.5)

ax.set_xlim(1e-3, 1e2)
ax.set_ylim(1e3, 1e6)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
eps = 1e-7
rho_thr_V, e_thr_V = 1, 2
rho_thr_S, e_thr_S = 1, 2
rho_thr_F, e_thr_F = 1, 2
rho_thr_K, e_thr_K = 1, 2

hp_V = jnp.exp(-jnp.power(((rho_V + eps) / rho_thr_V + eps), -e_thr_V))
hp_S = jnp.exp(-jnp.power(((rho_S + eps) / rho_thr_S + eps), -e_thr_S))
hp_F = jnp.exp(-jnp.power(((rho_F + eps) / rho_thr_F + eps), -e_thr_F))
hp_K = jnp.exp(-jnp.power(((rho_K + eps) / rho_thr_K + eps), -e_thr_K))

rho2_V = rho_V * hp_V
rho2_S = rho_S * hp_S
rho2_F = rho_F * hp_F
rho2_K = rho_K * hp_K

bins = jnp.logspace(-5, 2, 200)

dist2_V, bin_edges = jnp.histogram(rho2_V, bins)
dist2_S, bin_edges = jnp.histogram(rho2_S, bins)
dist2_F, bin_edges = jnp.histogram(rho2_F, bins)
dist2_K, bin_edges = jnp.histogram(rho2_K, bins)

bin_difs = bins[1:]-bins[:-1]
bin_centers = bin_difs*0.5

dists2 = [dist2_V, dist2_S, dist2_F, dist2_K]

# %%
fs, rat = 7, 2.5
fig, ax = plt.subplots(1, 1, figsize=(fs * rat, fs))

lw = 0.25*fs
alpha = 1
cs = ["b", "r", "g", "y", 'k']

for i in range(4):
    ax.step(
        bins[:-1] + bin_difs / 2,
        dists2[i],
        where='mid',
        color=cs[i],
        alpha=alpha,
        zorder=10,
        linewidth=lw,
    )

ax.grid(True, alpha=0.5)

ax.set_xlim(1e-3, 1e2)
ax.set_ylim(1e3, 1e6)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')
